# %% [markdown]
# In this activity you'll have a chance to play with a so-called N-body simulator: a code that models the gravitational interaction among bodies.
# Using this simple python code, we modelled the planets of our solar system orbiting around our Sun. Afterwards, you'll have a chance to play around to see what happens to our planets if some of their values change! Play around changing masses, number of bodies, and distances to find out what happens to the system!

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.core.display import HTML

# %% [markdown]
# Here starts the simulation. Let's establish the initial values for our planets

# %%
# Gravitational constant in m^3 kg^-1 s^-2
G = 6.67430e-11  

# Masses of the Sun, Earth, Mercury, Venus, Mars, Jupiter, Saturn, Uranus, and Neptune
masses = np.array([1.989e30, 5.972e24, 3.301e23, 4.867e24, 6.417e23, 1.898e27, 5.683e26, 8.681e25, 1.024e26])  

# Initial positions and velocities (meters and m/s)
positions = np.array([[0, 0, 0], [147e9, 0, 0], [57.9e9, 0, 0], [108.2e9, 0, 0], [227.9e9, 0, 0], [778.3e9, 0, 0], [1.429e12, 0, 0], [2.871e12, 0, 0], [4.498e12, 0, 0]])  
velocities = np.array([[0, 0, 0], [0, 30e3, 0], [0, 47.87e3, 0], [0, 35e3, 0], [0, 24.07e3, 0], [0, 13.07e3, 0], [0, 9.69e3, 0], [0, 6.8e3, 0], [0, 5.43e3, 0]])  

# Time parameters
dt = 1*60 * 60 * 24  # Time step in seconds (1 day)
total_time = 165 * 365 * 24 * 60 * 60  # 165 years in seconds (165 is Neptune's orbital period)

# %% [markdown]
# Now we set the colors and labels for our animation

# %%
# Colors and labels for plotting
colors = ['gold', 'blue', 'red', 'orange', 'brown', 'grey', 'green', 'cyan', 'blueviolet']  
labels = ['Sun', 'Earth', 'Mercury', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

# %% [markdown]
# Below is the actual simulation code. After running this cell look thorough the main page. You will find a gif called 'solar_system.gif'. Everytime you run this code changing the parameters, the gif will get overwritten.

# %%
# Number of bodies
num_bodies = len(masses)

def calculate_force(pos1, pos2, mass1, mass2):
    '''
    A simple function to calculate the gravitational force vector exerted on the first body by the second body 
    using Newton's law of gravitation

    Args:
        pos1 : numpy array - the position of the first body at a given moment
        pos2 : numpy array - the position of the second body at a given moment
        pos1 : float - the mass of the first body at a given moment
        pos2 : float - the mass of the second body at a given moment
    '''
    r = pos2 - pos1
    r_magnitude = np.linalg.norm(r)
    force_magnitude = G * (mass1 * mass2) / (r_magnitude ** 2)
    force = force_magnitude * (r / r_magnitude)
    return force


def update_positions_and_velocities(positions, velocities, masses, dt):
    '''
    A simple function that uses Eulers integration to update the bodies positions and velocities over time
    
    Args:
        positions : numpy array - the position vectors for each body
        velocities : numpy array - the velocity vectors for each body
        masses : numpy array  - the masses of each body
        dt : float - the integration time step
    '''
    num_bodies = len(masses)
    forces = np.zeros_like(positions)

    for i in range(num_bodies):
        for j in range(num_bodies):
            if i != j:
                force = calculate_force(positions[i], positions[j], masses[i], masses[j])
                forces[i] += force

    for i in range(num_bodies):
        acceleration = forces[i] / masses[i]
        velocities[i] += acceleration * dt
        positions[i] += velocities[i] * dt

    return positions, velocities

# Plot and animation setup
fig, ax = plt.subplots()
points, = ax.plot([], [], 'o')

# Store the points for each body separately, set color and labels for each planet
scatter_points = [ax.plot([], [], 'o', color=colors[i], label=labels[i], markersize=3)[0] for i in range(num_bodies)]

# Time counter 
time_counter_text = plt.text(0.05, 0.95, '', transform=plt.gca().transAxes, color='black', fontsize=10)

def init():
    '''
    The animation initialization, returns the scatter points for the animation
    '''
    #the size of the displayed x and y axis
    ax.set_xlim(-5e12, 5e12)
    ax.set_ylim(-5e12, 5e12)

    for scatter_point in scatter_points:
        scatter_point.set_data([], [])

    ax.legend()
    time_counter_text.set_text('')
    return scatter_points + [time_counter_text]

def update(frame):
    """
    A simple function to update the positions of the bodies for each frame of the animation. Returns updated scatter points plot

    Args:
        frame (int): the current frame number.

    """
    global positions, velocities
    positions, velocities = update_positions_and_velocities(positions, velocities, masses, dt)
    
    for i in range(num_bodies):
        scatter_points[i].set_data(positions[i, 0], positions[i, 1])
    
    # Update time counter 
    current_time_years = frame * dt / (60 * 60 * 24 * 365)
    time_counter_text.set_text(f'Time: {current_time_years:.2f} years')

    return scatter_points + [time_counter_text]




plt.scatter(147e9, 0)
plt.scatter(4.498e12, 0)

# Create and save animation
ani = FuncAnimation(fig, update, frames=int(total_time/dt), init_func=init, blit=True, interval=10)

out = HTML(ani.to_html5_video())
ani.save('solar_system.gif', writer = 'PillowWriter', fps=15)


plt.show()
# Out:
# /var/folders/3r/7j27g_2j601cfh1mb4shyy5m0000gn/T/ipykernel_9154/687206187.py:85: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   scatter_points[i].set_data(positions[i, 0], positions[i, 1])
# MovieWriter PillowWriter unavailable; using Pillow instead.
# /var/folders/3r/7j27g_2j601cfh1mb4shyy5m0000gn/T/ipykernel_9154/687206187.py:85: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   scatter_points[i].set_data(positions[i, 0], positions[i, 1])

# %% [markdown]
# Now it's your turn to play around with the code! Add or remove as many planets as you like. To change the masses, positions, initial velocities, or number of planets, just add, remove, and modify the corresponding numbers in the numpy arrays (np.array()). Just make sure you have the same number of elements in each array! (ex. 3 planets, 3 masses, 3 velocities, 3 positiona, 3 colors, 3 labels).
#
# The values below show a simple Sun, Earth, Mercury, Venus system but for a 3 times the normal solar mass! Try run it to see what it looks like! You will find a file named 'n-body-system.gif' on the main page after running the code. As before, the gif will get overwritten each time you run it.
#
# Note: depending on your initial values you might see nothing. One possible reason is that the planet has escaped! Try adjusting the limits of the graph (i.e. how big of a space you are observing) to see what happened! You can set it by changing the values of xlim and ylim you can find in the code below.
#
# "def init(): ax.set_xlim(-1e12, 1e12) ax.set_ylim(-1e12, 1e12)"

# %%
# Gravitational constant
G = 6.67430e-11  # m^3 kg^-1 s^-2


# Masses of the Sun, Earth, Mercury, Venus
masses = np.array([3.989e30, 5.972e24, 3.301e23, 4.867e24,])  

# Initial positions and velocities (meters and m/s)
positions = np.array([[0, 0, 0], [147e9, 0, 0], [57.9e9, 0, 0], [108.2e9, 0, 0]])  
velocities = np.array([[0, 0, 0], [0, 30e3, 0], [0, 47.87e3, 0], [0, 35e3, 0]]) 

# Colors and labels for plotting
colors = ['gold', 'blue', 'red', 'orange']  
labels = ['Sun', 'Earth', 'Mercury', 'Venus']

# %% [markdown]
# How many years do you want to run the simulation form? Note: since we are using a numerical method to do a prediction, the longer you choose the more inaccurate the animation will be

# %%
# Time parameters

years = 20 #how many years do you want to run the simulation for?

dt = 1.2*60 * 60 * 24  # Time step in seconds (1.2 days)
total_time = years * 365 * 24 * 60 * 60  # n years in seconds

# %% [markdown]
# Now let's run the animation! Go back to the main directory once the script is done running.

# %%
# Number of bodies
num_bodies = len(masses)


def calculate_force(pos1, pos2, mass1, mass2):
    '''
    A simple function to calculate the gravitational force vector exerted on the first body by the second body 
    using Newton's law of gravitation

    Args:
        pos1 : numpy array - the position of the first body at a given moment
        pos2 : numpy array - the position of the second body at a given moment
        pos1 : float - the mass of the first body at a given moment
        pos2 : float - the mass of the second body at a given moment
    '''
    r = pos2 - pos1
    r_magnitude = np.linalg.norm(r)
    force_magnitude = G * (mass1 * mass2) / (r_magnitude ** 2)
    force = force_magnitude * (r / r_magnitude)
    return force


def update_positions_and_velocities(positions, velocities, masses, dt):
    '''
    A simple function that uses Eulers integration to update the bodies positions and velocities over time
    
    Args:
        positions : numpy array - the position vectors for each body
        velocities : numpy array - the velocity vectors for each body
        masses : numpy array  - the masses of each body
        dt : float - the integration time step
    '''
    num_bodies = len(masses)
    forces = np.zeros_like(positions)

    for i in range(num_bodies):
        for j in range(num_bodies):
            if i != j:
                force = calculate_force(positions[i], positions[j], masses[i], masses[j])
                forces[i] += force

    for i in range(num_bodies):
        acceleration = forces[i] / masses[i]
        velocities[i] += acceleration * dt
        positions[i] += velocities[i] * dt

    return positions, velocities

# Plot and animation setup
fig, ax = plt.subplots()
points, = ax.plot([], [], 'o')

# Store the points for each body separately, set color and labels for each planet
scatter_points = [ax.plot([], [], 'o', color=colors[i], label=labels[i], markersize=3)[0] for i in range(num_bodies)]

# Time counter 
time_counter_text = plt.text(0.05, 0.94, '', transform=plt.gca().transAxes, color='black', fontsize=10)

def init():
    '''
    The animation initialization, returns the scatter points for the animation
    '''
    #the size of the displayed x and y axis
    ax.set_xlim(-5e12, 5e12)
    ax.set_ylim(-5e12, 5e12)

    for scatter_point in scatter_points:
        scatter_point.set_data([], [])

    ax.legend()
    time_counter_text.set_text('')
    return scatter_points + [time_counter_text]

def update(frame):
    """
    A simple function to update the positions of the bodies for each frame of the animation. Returns updated scatter points plot

    Args:
        frame (int): the current frame number.

    """
    global positions, velocities
    positions, velocities = update_positions_and_velocities(positions, velocities, masses, dt)
    
    for i in range(num_bodies):
        scatter_points[i].set_data(positions[i, 0], positions[i, 1])
    
    # Update time counter 
    current_time_years = frame * dt / (60 * 60 * 24 * 365)
    time_counter_text.set_text(f'Time: {current_time_years:.2f} years')

    return scatter_points + [time_counter_text]


# Create animation
ani = FuncAnimation(fig, update, frames=int(total_time/dt), init_func=init, blit=True, interval=10)


out = HTML(ani.to_html5_video())
ani.save('3-body-system.gif', writer = 'PillowWriter', fps=15)
